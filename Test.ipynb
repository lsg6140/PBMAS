# %%
# %run std.py

# %%
# %run solve_ode.py
# Out:
# Solving ODE...

# %%
# %run plotting.py
# Out:
# solving ODE took 21.79 seconds

# %%
from data_import import importing
length, volume, number, Y0, mu, sigma, time, n, N, p, Q = importing(1)

# %%
import numpy as np
from plotting import plot

# %%
k = np.array([1e-5, 0.5, 0.3, 3.0, 10.0])
r = plot(k)
# Out:
# solving ODE took 49.49 seconds
# SSE is  0.019818180975649326
# /home/lsg/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
k = np.array([1e-6, 0.5, 0.3, 3.0, 10.0])
r2 = plot(k)
# Out:
# solving ODE took 32.91 seconds
# SSE is  0.06581877662738292

# %%
r2
# Out:
# array([[ 0.00000000e+00, -1.31710167e-01, -2.07831182e-01,
#         -2.84588886e-01, -3.61900269e-01, -4.83063176e-01],
#        [ 0.00000000e+00, -1.40571696e-02, -1.73708473e-02,
#         -1.57032491e-02,  5.86154567e-02, -7.63641786e-03],
#        [ 0.00000000e+00, -1.87161648e-02, -2.25754819e-02,
#         -1.92888446e-02,  8.78043716e-02,  4.13279116e-03],
#        [ 0.00000000e+00, -2.63681958e-02, -3.18339014e-02,
#         -2.77351957e-02,  1.17155438e-01,  2.03048118e-02],
#        [ 0.00000000e+00, -3.89687040e-02, -4.78541997e-02,
#         -4.40916062e-02,  1.45254598e-01,  4.35568254e-02],
#        [ 0.00000000e+00, -5.69598576e-02, -7.13531867e-02,
#         -6.95424047e-02,  1.67734686e-01,  7.77970480e-02],
#        [ 0.00000000e+00, -7.90841742e-02, -1.00735402e-01,
#         -1.02737255e-01,  1.76370227e-01,  1.22040400e-01],
#        [ 0.00000000e+00, -1.01502162e-01, -1.30958147e-01,
#         -1.38049484e-01,  1.66528814e-01,  1.71733227e-01],
#        [ 0.00000000e+00, -1.15773701e-01, -1.49724795e-01,
#         -1.59698792e-01,  1.51435561e-01,  2.33350312e-01],
#        [ 0.00000000e+00, -1.16722671e-01, -1.50265608e-01,
#         -1.59702351e-01,  1.35031917e-01,  2.92683195e-01],
#        [ 0.00000000e+00, -1.04258096e-01, -1.33595457e-01,
#         -1.40661769e-01,  1.10889482e-01,  3.12647313e-01],
#        [ 0.00000000e+00, -8.53632848e-02, -1.10302466e-01,
#         -1.16950953e-01,  6.76257433e-02,  2.53135982e-01],
#        [ 0.00000000e+00, -6.67908475e-02, -8.84424818e-02,
#         -9.68979346e-02,  1.69384242e-02,  1.41072478e-01],
#        [ 0.00000000e+00, -4.74169101e-02, -6.36967908e-02,
#         -7.10428590e-02, -6.44253141e-03,  6.15319361e-02],
#        [ 0.00000000e+00, -2.87929381e-02, -3.79874490e-02,
#         -4.09504707e-02, -1.66631183e-03,  3.52795530e-02],
#        [ 0.00000000e+00, -1.52329504e-02, -1.89572005e-02,
#         -1.82382337e-02,  7.06976539e-03,  2.66848671e-02],
#        [ 0.00000000e+00, -7.59130098e-03, -8.58535807e-03,
#         -6.69016157e-03,  9.17968493e-03,  1.75125528e-02],
#        [ 0.00000000e+00, -3.47299946e-03, -3.15525250e-03,
#         -8.35048406e-04,  9.36981840e-03,  1.26584826e-02],
#        [ 0.00000000e+00, -1.54626351e-03, -9.05568343e-04,
#          1.01444705e-03,  7.71282846e-03,  9.11677416e-03],
#        [ 0.00000000e+00, -7.26256027e-04, -1.39808167e-04,
#          1.27507967e-03,  5.63137159e-03,  6.18179842e-03],
#        [ 0.00000000e+00, -3.72721640e-04,  6.64743975e-05,
#          1.03276189e-03,  3.86924428e-03,  4.09892416e-03],
#        [ 0.00000000e+00, -1.70332730e-04,  1.56876806e-04,
#          8.02846994e-04,  2.68212893e-03,  2.81729303e-03],
#        [ 0.00000000e+00, -4.53268476e-05,  1.98559853e-04,
#          6.26300836e-04,  1.87301688e-03,  1.93308610e-03],
#        [ 0.00000000e+00,  1.72601549e-05,  1.93586971e-04,
#          4.84716404e-04,  1.30522647e-03,  1.28510143e-03],
#        [ 0.00000000e+00,  4.09902301e-05,  1.77199685e-04,
#          3.88776517e-04,  9.26649351e-04,  8.53274584e-04],
#        [ 0.00000000e+00,  5.03530456e-05,  1.68519677e-04,
#          3.27001761e-04,  6.65882930e-04,  5.54454982e-04],
#        [ 0.00000000e+00,  5.72437312e-05,  1.61531180e-04,
#          2.85668090e-04,  4.84740246e-04,  3.52738092e-04],
#        [ 0.00000000e+00,  6.27938283e-05,  1.60054293e-04,
#          2.52710318e-04,  3.51343244e-04,  2.17250415e-04],
#        [ 0.00000000e+00,  6.92174347e-05,  1.55804084e-04,
#          2.22588660e-04,  2.49831444e-04,  1.26015394e-04],
#        [ 0.00000000e+00,  7.24578769e-05,  1.46632015e-04,
#          1.89993091e-04,  1.71349884e-04,  6.58453310e-05],
#        [ 0.00000000e+00,  7.23459977e-05,  1.31555868e-04,
#          1.55686908e-04,  1.12951035e-04,  2.91575415e-05],
#        [ 0.00000000e+00,  6.79223952e-05,  1.11474950e-04,
#          1.21400087e-04,  7.18985756e-05,  9.68806457e-06],
#        [ 0.00000000e+00,  6.03359614e-05,  8.94683521e-05,
#          9.05514919e-05,  4.58092233e-05,  2.30519276e-06],
#        [ 0.00000000e+00,  5.03933437e-05,  6.75638465e-05,
#          6.47778055e-05,  2.74874337e-05, -2.70827653e-06],
#        [ 0.00000000e+00,  3.94075424e-05,  4.79136360e-05,
#          4.48453510e-05,  1.33675952e-05, -4.45480275e-06],
#        [ 0.00000000e+00,  2.87545636e-05,  3.20419853e-05,
#          2.70643247e-05,  5.41355277e-06, -4.00495770e-06],
#        [ 0.00000000e+00,  1.94688789e-05,  2.03384888e-05,
#          1.49693163e-05,  1.02606209e-06, -3.50230743e-06],
#        [ 0.00000000e+00,  1.21633330e-05,  1.11341894e-05,
#          6.76645008e-06, -1.01290914e-06, -2.85338062e-06],
#        [ 0.00000000e+00,  6.97765979e-06,  4.98808417e-06,
#          2.14436314e-06, -1.73526018e-06, -2.24070878e-06],
#        [ 0.00000000e+00,  3.64116759e-06,  1.53970332e-06,
#         -1.30046541e-07, -1.78608223e-06, -1.70948294e-06],
#        [ 0.00000000e+00,  1.34594086e-06, -1.37590341e-07,
#         -1.01714464e-06, -1.53531277e-06, -1.25352077e-06],
#        [ 0.00000000e+00,  1.52744918e-07, -7.75983851e-07,
#         -1.17838253e-06, -1.18461561e-06, -8.66509289e-07],
#        [ 0.00000000e+00, -3.56911122e-07, -8.76238080e-07,
#         -1.01830275e-06, -8.37221314e-07, -5.50417146e-07],
#        [ 0.00000000e+00, -4.89328172e-07, -7.43706133e-07,
#         -7.59347135e-07, -5.42491037e-07, -3.10779975e-07],
#        [ 0.00000000e+00, -4.44341451e-07, -5.45674802e-07,
#         -5.04982705e-07, -3.19382618e-07, -1.48358721e-07],
#        [ 0.00000000e+00, -3.39742494e-07, -3.62970228e-07,
#         -3.11172233e-07, -1.68765754e-07, -5.42506524e-08],
#        [ 0.00000000e+00, -2.35980835e-07, -2.25134035e-07,
#         -1.77237199e-07, -7.90875505e-08, -1.04947648e-08],
#        [ 0.00000000e+00, -1.39374131e-07, -1.20328608e-07,
#         -8.60445600e-08, -2.82067139e-08,  5.34166538e-09],
#        [ 0.00000000e+00, -7.19709208e-08, -5.57509343e-08,
#         -3.50987207e-08, -6.52288709e-09,  6.68221731e-09],
#        [ 0.00000000e+00, -3.29572311e-08, -2.23067525e-08,
#         -1.16955547e-08,  7.48268191e-11,  4.28270920e-09],
#        [ 0.00000000e+00, -1.31516482e-08, -7.36203576e-09,
#         -2.83186987e-09,  1.20645789e-09,  2.31952787e-09],
#        [ 0.00000000e+00, -4.37830302e-09, -1.76096273e-09,
#         -2.50793726e-10,  1.00001914e-09,  1.24813886e-09],
#        [ 0.00000000e+00, -1.10574982e-09, -1.44123626e-10,
#          1.91927669e-10,  6.41125893e-10,  6.78605372e-10],
#        [ 0.00000000e+00, -1.60815765e-10,  1.18412087e-10,
#          1.35380616e-10,  3.48922163e-10,  3.46403495e-10],
#        [ 0.00000000e+00,  3.98037856e-12,  8.04980392e-11,
#          5.29486278e-11,  1.48938496e-10,  1.54166041e-10],
#        [ 0.00000000e+00,  2.67255816e-12,  2.85773803e-11,
#          1.17599663e-11,  4.88006478e-11,  5.64465092e-11],
#        [ 0.00000000e+00, -5.09655935e-12, -1.86809247e-13,
#         -1.35729052e-15, -7.88341163e-21, -1.61060321e-24],
#        [ 0.00000000e+00, -9.86944740e-13, -1.08757102e-14,
#         -1.45783083e-17, -1.36251754e-23, -2.74434839e-25],
#        [ 0.00000000e+00, -1.15121901e-13, -2.34263896e-16,
#         -4.30154840e-20, -1.93357336e-26,  2.89575058e-25],
#        [ 0.00000000e+00, -6.24609710e-15, -9.30352889e-19,
#         -5.12351722e-23, -9.61595186e-29,  1.33955419e-26],
#        [ 0.00000000e+00, -1.06614294e-16,  1.41127927e-21,
#         -5.23813887e-26,  2.41414035e-30, -1.69996489e-26]])

# %%
import benchmark

# %%
benchmark.breakage()
# Out:
# breakage function takes 30.13 μs.

# %%
benchmark.breakage('cython')
# Out:
# breakage function takes  1.71 μs.

# %%
benchmark.selection()
# Out:
# breakage function takes  0.58 μs.

# %%
benchmark.selection('cython')
# Out:
# breakage function takes  0.52 μs.

# %%
benchmark.discretize_cython_check()
# Out:
# No error

# %%
benchmark.discretize_cython_check()
# Out:
# No error

# %%
benchmark.discretize_parallel_check()
# Out:
# No error

# %%
benchmark.discretize()
# Out:
# discretization of breakage takes 24.634 s.
# discretization of selection takes 10.410 s.

# %%
benchmark.discretize('cython')
# Out:
# discretization of breakage takes  1.900 s.
# discretization of selection takes  0.543 s.

# %%
benchmark.discretize('serial')
# Out:
# discretization of breakage takes  2.016 s.
# discretization of selection takes  0.592 s.

# %%
benchmark.discretize('parallel')
# Out:
# discretization of breakage takes  0.595 s.
# discretization of selection takes  0.181 s.

# %%
benchmark.ode_check()
# Out:
# No error

# %%
benchmark.ode()
# Out:
# constructing ode takes 296.97 μs.

# %%
benchmark.ode('cython')
# Out:
# constructing ode takes  5.64 μs.

# %%
benchmark.ode('parallel')
# Out:
# constructing ode takes 12.35 μs.

# %%
benchmark.phi_check()
# Out:
# No error

# %%
benchmark.phi_parallel_check()
# Out:
# No error

# %%
benchmark.phi()
# Out:
# constructing phi takes  1.10 ms.

# %%
benchmark.phi('cython')
# Out:
# constructing phi takes  0.49 ms.

# %%
benchmark.phi('parallel')
# Out:
# constructing phi takes  0.30 ms.

# %%
# %run discretize_parallel.py

# %%
# %run pbm.py

# %%
import numpy as np

import pbm
import gn_ode
    
from data_import import importing
    
k0 = np.array([1e-7, 0.9, 0.05])
length, volume, number, Y0, mu, sigma, t, n, N, p, Q = importing(k0)
args = [length, mu, sigma, 1]

# %%
res = gn_ode.gn_ode_bisection(pbm.phi, number, t, k0, Q, True, [1e-4, 1e-4, 100], *args)
# Out:
# get_fYHg: solve with parameters [1.e-07 9.e-01 5.e-02]
# Iter | Obj func | step size | gradient
#     0|1.7792e-01|  3.434e+02|  5.39e+03
# gn_ode: current step is [ 3.32247423e-05 -2.63645196e+02  2.20070628e+02]
# doing bisection
# get_fYHg_stepwise: solve with parameters [1.64892075e-07 3.85067976e-01 4.79825445e-01]
# bisection done with mu=0.001953125 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     1|1.7765e-01|  7.060e-02|  4.94e+03
# gn_ode: current step is [ 3.56934348e-05  2.46513563e+01 -2.64371282e+01]
# doing bisection
# get_fYHg_stepwise: solve with parameters [7.22601993e-07 7.70245419e-01 6.67453178e-02]
# bisection done with mu=0.015625 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     2|1.7443e-01|  2.915e-01|  5.45e+03
# gn_ode: current step is [ 3.66225477e-05 -1.27165062e+01  1.36530520e+01]
# doing bisection
# get_fYHg_stepwise: solve with parameters [1.86705661e-06 3.72854600e-01 4.93403193e-01]
# bisection done with mu=0.03125 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     3|1.6966e-01|  1.225e-01|  4.48e+03
# gn_ode: current step is [ 3.71211451e-05  2.68204878e+00 -2.86000160e+00]
# doing bisection
# get_fYHg_stepwise: solve with parameters [6.50719974e-06 7.08110697e-01 1.35902993e-01]
# bisection done with mu=0.125 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     4|1.4834e-01|  2.146e-01|  3.86e+03
# gn_ode: current step is [ 4.13891900e-05 -1.16770951e+00  1.25866963e+00]
# doing bisection
# get_fYHg_stepwise: solve with parameters [2.72017948e-05 1.24255942e-01 7.65237809e-01]
# bisection done with mu=0.5 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     5|1.0800e-01|  8.095e-01|  1.42e+03
# gn_ode: current step is [ 5.46535380e-05  1.11406596e+00 -1.17474766e+00]
# doing bisection
# get_fYHg_stepwise: solve with parameters [5.45285637e-05 6.81288921e-01 1.77863977e-01]
# bisection done with mu=0.5 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     6|6.5730e-02|  6.093e-02|  7.89e+02
# gn_ode: current step is [ 7.77574218e-05 -8.36679520e-02  8.86002680e-02]
# doing bisection
# get_fYHg_stepwise: solve with parameters [1.32285986e-04 5.97620969e-01 2.66464245e-01]
# bisection done with mu=1.0 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     7|3.5130e-02|  2.349e-01|  2.04e+02
# gn_ode: current step is [ 1.03460319e-04  1.71184770e-01 -1.60811092e-01]
# doing bisection
# get_fYHg_stepwise: solve with parameters [2.35746304e-04 7.68805739e-01 1.05653153e-01]
# bisection done with mu=1.0 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     8|2.2069e-02|  2.583e-02|  3.38e+01
# gn_ode: current step is [ 4.61346940e-05 -1.83666441e-02  1.81586912e-02]
# doing bisection
# get_fYHg_stepwise: solve with parameters [2.81880998e-04 7.50439095e-01 1.23811844e-01]
# bisection done with mu=1.0 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     9|2.1251e-02|  2.967e-03|  2.17e+00
# gn_ode: current step is [ 4.27962816e-06 -1.26345744e-03  2.68435189e-03]
# doing bisection
# get_fYHg_stepwise: solve with parameters [2.86160626e-04 7.49175637e-01 1.26496196e-01]
# bisection done with mu=1.0 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#    10|2.1245e-02|  7.924e-04|  3.70e-02
# gn_ode: current step is [-8.36426405e-08 -5.23175878e-04  5.95174978e-04]
# doing bisection
# get_fYHg_stepwise: solve with parameters [2.86076984e-04 7.48652462e-01 1.27091371e-01]
# bisection done with mu=1.0 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#    11|2.1245e-02|  9.389e-05|  2.52e-02
# gn_ode: current step is [ 5.24361575e-08  6.73463591e-05 -6.54165290e-05]
# doing bisection
# get_fYHg_stepwise: solve with parameters [2.86129420e-04 7.48719808e-01 1.27025954e-01]
# bisection done with mu=1.0 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#    12|2.1245e-02|  2.193e-05|  4.33e-03
# gn_ode: termination by stepsize

# %%
import matplotlib.pyplot as plt
import numpy as np

V = np.empty(np.shape(res[1]))
for i in range(6):
    V[:,i] = np.multiply(res[1][:,i], length**3)
fig, axes = plt.subplots(6,1,figsize=(5,10))
for i in range(6):
    axes[i].plot(length,V[:,i])
    axes[i].scatter(length,volume[:,i])
    axes[i].set_xscale('log')
    axes[i].set_xlim([length[0],length[-1]])
    axes[i].title.set_text('t={0}'.format(t[i]))

# %%
import pbm
import lm_ode
    
from data_import import importing
    
k0 = np.array([1e-7, 0.9, 0.05])
length, volume, number, Y0, mu, sigma, t, n, N, p, Q = importing(k0)
args = [length, mu, sigma, 3]

# %%
args = [length, mu, sigma, 3]
res = gn_ode.gn_ode_bisection(pbm.phi, number, t, k0, Q, True, [1e-5, 1e-5, 100], *args)
# Out:
# get_fYHg: solve with parameters [1.e-07 9.e-01 5.e-02]
# Iter | Obj func | step size | gradient
#     0|2.4725e-02|  3.756e-01|  9.06e+04
# gn_ode: current step is [ 8.58654689e-08 -3.05769726e-01  2.18077677e-01]
# doing bisection
# get_fYHg_stepwise: solve with parameters [1.85865469e-07 5.94230274e-01 2.68077677e-01]
# bisection done with mu=1.0 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     1|1.5468e-02|  7.037e-02|  2.56e+04
# gn_ode: current step is [ 5.91070858e-08  5.57247870e-02 -4.29763869e-02]
# doing bisection
# get_fYHg_stepwise: solve with parameters [2.44972555e-07 6.49955061e-01 2.25101290e-01]
# bisection done with mu=1.0 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     2|1.4255e-02|  7.868e-04|  4.47e+03
# gn_ode: current step is [ 2.11523013e-08 -6.83804431e-04 -3.89140697e-04]
# doing bisection
# get_fYHg_stepwise: solve with parameters [2.66124856e-07 6.49271256e-01 2.24712149e-01]
# bisection done with mu=1.0 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     3|1.4205e-02|  7.566e-04|  4.08e+02
# gn_ode: current step is [ 2.26567369e-09  5.54684580e-04 -5.14531627e-04]
# doing bisection
# get_fYHg_stepwise: solve with parameters [2.68390530e-07 6.49825941e-01 2.24197617e-01]
# bisection done with mu=1.0 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     4|1.4205e-02|  4.084e-05|  2.14e+01
# gn_ode: current step is [ 1.21233461e-10  2.91425193e-05 -2.86063496e-05]
# doing bisection
# get_fYHg_stepwise: solve with parameters [2.68511763e-07 6.49855084e-01 2.24169011e-01]
# bisection done with mu=1.0 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     5|1.4205e-02|  2.135e-06|  1.01e+00
# gn_ode: termination by stepsize

# %%
V = np.empty(np.shape(res[1]))
for i in range(6):
    V[:,i] = np.multiply(res[1][:,i], length**3)
fig, axes = plt.subplots(6,1,figsize=(5,10))
for i in range(6):
    axes[i].plot(length,V[:,i])
    axes[i].scatter(length,volume[:,i])
    axes[i].set_xscale('log')
    axes[i].set_xlim([length[0],length[-1]])
    axes[i].title.set_text('t={0}'.format(t[i]))

# %%
args = [length, mu, sigma, 2]
res = gn_ode.gn_ode_bisection(pbm.phi, number, t, k0, Q, True, [1e-5, 1e-5, 100], *args)
# Out:
# get_fYHg: solve with parameters [1.e-07 9.e-01 5.e-02]
# Iter | Obj func | step size | gradient
#     0|1.4455e-01|  2.179e+00|  2.49e+05
# gn_ode: current step is [ 5.98509075e-07 -1.70168336e+00  1.36095833e+00]
# doing bisection
# get_fYHg_stepwise: solve with parameters [3.99254538e-07 4.91583186e-02 7.30479167e-01]
# bisection done with mu=0.5 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     1|1.1127e-01|  7.629e-01|  8.41e+04
# gn_ode: current step is [ 9.12535905e-07  1.18452592e+00 -9.61776140e-01]
# doing bisection
# get_fYHg_stepwise: solve with parameters [8.55522490e-07 6.41421276e-01 2.49591098e-01]
# bisection done with mu=0.5 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     2|7.0294e-02|  6.152e-02|  4.67e+04
# gn_ode: current step is [ 1.44722128e-06 -1.03509300e-01  6.65092864e-02]
# doing bisection
# get_fYHg_stepwise: solve with parameters [2.30274377e-06 5.37911977e-01 3.16100384e-01]
# bisection done with mu=1.0 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     3|3.6889e-02|  1.531e-01|  1.22e+04
# gn_ode: current step is [ 2.44655524e-06  1.18364559e-01 -9.71299608e-02]
# doing bisection
# get_fYHg_stepwise: solve with parameters [4.74929902e-06 6.56276536e-01 2.18970423e-01]
# bisection done with mu=1.0 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     4|1.9555e-02|  1.106e-02|  2.91e+03
# gn_ode: current step is [ 2.72934373e-06  4.04000449e-03 -1.02987721e-02]
# doing bisection
# get_fYHg_stepwise: solve with parameters [7.47864275e-06 6.60316540e-01 2.08671651e-01]
# bisection done with mu=1.0 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     5|1.5545e-02|  1.777e-02|  4.89e+02
# gn_ode: current step is [ 1.27206269e-06  1.36161745e-02 -1.14201670e-02]
# doing bisection
# get_fYHg_stepwise: solve with parameters [8.75070544e-06 6.73932715e-01 1.97251484e-01]
# bisection done with mu=1.0 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     6|1.5218e-02|  2.236e-04|  1.67e+01
# gn_ode: current step is [6.33540698e-08 1.41193006e-04 1.73346993e-04]
# doing bisection
# get_fYHg_stepwise: solve with parameters [8.81405951e-06 6.74073908e-01 1.97424831e-01]
# bisection done with mu=1.0 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     7|1.5218e-02|  4.593e-05|  1.11e+00
# gn_ode: current step is [-4.17296746e-09 -2.10678568e-05  4.08123796e-05]
# doing bisection
# get_fYHg_stepwise: solve with parameters [8.80988655e-06 6.74052840e-01 1.97465643e-01]
# bisection done with mu=1.0 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     8|1.5218e-02|  3.477e-06|  8.75e-02
# gn_ode: termination by stepsize

# %%
V = np.empty(np.shape(res[1]))
for i in range(6):
    V[:,i] = np.multiply(res[1][:,i], length**3)
fig, axes = plt.subplots(6,1,figsize=(5,10))
for i in range(6):
    axes[i].plot(length,V[:,i])
    axes[i].scatter(length,volume[:,i])
    axes[i].set_xscale('log')
    axes[i].set_xlim([length[0],length[-1]])
    axes[i].title.set_text('t={0}'.format(t[i]))

# %%
args = [length, mu, sigma, 0]
res = gn_ode.gn_ode_bisection(pbm.phi, number, t, k0, Q, True, [1e-5, 1e-5, 100], *args)
# Out:
# get_fYHg: solve with parameters [1.e-07 9.e-01 5.e-02]
# Iter | Obj func | step size | gradient
#     0|1.7845e-01|  9.531e+03|  8.89e+01
# gn_ode: current step is [ 2.65161042e-03 -7.71724244e+03  5.59256595e+03]
# doing bisection
# get_fYHg_stepwise: solve with parameters [2.61841456e-07 4.28976902e-01 3.91343137e-01]
# bisection done with mu=6.103515625e-05 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     1|1.7844e-01|  1.060e-01|  7.94e+01
# gn_ode: current step is [ 2.47434802e-03  1.40620834e+03 -1.01992807e+03]
# doing bisection
# get_fYHg_stepwise: solve with parameters [8.65930329e-07 7.72289484e-01 1.42337260e-01]
# bisection done with mu=0.000244140625 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     2|1.7839e-01|  1.660e-01|  8.51e+01
# gn_ode: current step is [ 2.49129798e-03 -5.50322646e+02  3.99153929e+02]
# doing bisection
# get_fYHg_stepwise: solve with parameters [3.29883851e-06 2.34865025e-01 5.32136019e-01]
# bisection done with mu=0.0009765625 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     3|1.7821e-01|  3.124e-01|  7.64e+01
# gn_ode: current step is [ 2.47982073e-03  2.58995080e+02 -1.87787677e+02]
# doing bisection
# get_fYHg_stepwise: solve with parameters [8.14223836e-06 7.40714791e-01 1.65363212e-01]
# bisection done with mu=0.001953125 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     4|1.7778e-01|  1.178e-01|  8.40e+01
# gn_ode: current step is [ 2.48428448e-03 -4.88783873e+01  3.53534212e+01]
# doing bisection
# get_fYHg_stepwise: solve with parameters [2.75507108e-05 3.58852390e-01 4.41561815e-01]
# bisection done with mu=0.0078125 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     5|1.7633e-01|  1.956e-01|  7.67e+01
# gn_ode: current step is [ 2.48359299e-03  2.03095304e+01 -1.46371817e+01]
# doing bisection
# get_fYHg_stepwise: solve with parameters [6.63568513e-05 6.76188802e-01 2.12855850e-01]
# bisection done with mu=0.015625 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     6|1.7307e-01|  6.268e-02|  7.92e+01
# gn_ode: current step is [ 2.48890816e-03 -3.28525701e+00  2.30192686e+00]
# doing bisection
# get_fYHg_stepwise: solve with parameters [3.77470371e-04 2.65531676e-01 5.00596708e-01]
# bisection done with mu=0.125 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     7|1.5327e-01|  4.211e-01|  5.73e+01
# gn_ode: current step is [ 2.59431041e-03  2.78418630e+00 -1.89624153e+00]
# doing bisection
# get_fYHg_stepwise: solve with parameters [0.00102605 0.96157825 0.02653632]
# bisection done with mu=0.25 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     8|1.1676e-01|  2.049e-01|  4.07e+01
# gn_ode: current step is [ 0.00157696 -0.74505542  0.34179331]
# doing bisection
# get_fYHg_stepwise: solve with parameters [0.002603   0.21652283 0.36832963]
# bisection done with mu=1.0 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#     9|9.9837e-02|  1.654e+00|  5.93e+00
# gn_ode: current step is [ 0.00355682  1.51872578 -0.65582104]
# doing bisection
# get_fYHg_stepwise: solve with parameters [0.00349221 0.59620427 0.20437437]
# bisection done with mu=0.25 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#    10|7.0220e-02|  1.832e-01|  7.84e+00
# gn_ode: current step is [ 0.00352011  0.62313949 -0.3857529 ]
# doing bisection
# get_fYHg_stepwise: solve with parameters [0.00525226 0.90777402 0.01149792]
# bisection done with mu=0.5 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#    11|4.8335e-02|  3.297e-02|  4.06e+00
# gn_ode: current step is [ 0.00168283  0.03684135 -0.05465103]
# doing bisection
# get_fYHg_stepwise: solve with parameters [0.00546262 0.91237919 0.00466654]
# bisection done with mu=0.125 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#    12|4.7445e-02|  6.343e-03|  3.53e+00
# gn_ode: current step is [ 0.00153516  0.02865692 -0.04184807]
# doing bisection
# get_fYHg_stepwise: solve with parameters [0.00555857 0.91417024 0.00205104]
# bisection done with mu=0.0625 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#    13|4.7087e-02|  2.788e-03|  3.29e+00
# gn_ode: current step is [ 0.00146648  0.02529969 -0.03670844]
# doing bisection
# get_fYHg_stepwise: solve with parameters [5.60439249e-03 9.14960860e-01 9.03898320e-04]
# bisection done with mu=0.03125 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#    14|4.6926e-02|  1.308e-03|  3.19e+00
# gn_ode: current step is [ 0.00143347  0.02378523 -0.03440664]
# doing bisection
# get_fYHg_stepwise: solve with parameters [5.62679042e-03 9.15332504e-01 3.66294596e-04]
# bisection done with mu=0.015625 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#    15|4.6850e-02|  6.334e-04|  3.14e+00
# gn_ode: current step is [ 0.00141729  0.02306034 -0.03331001]
# doing bisection
# get_fYHg_stepwise: solve with parameters [5.63786301e-03 9.15512663e-01 1.06060144e-04]
# bisection done with mu=0.0078125 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#    16|4.6812e-02|  3.117e-04|  3.11e+00
# gn_ode: current step is [ 0.00140932  0.02270849 -0.0327781 ]
# doing bisection
# get_fYHg_stepwise: solve with parameters [5.64061558e-03 9.15557016e-01 4.20404088e-05]
# bisection done with mu=0.001953125 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#    17|4.6803e-02|  7.762e-05|  3.10e+00
# gn_ode: current step is [ 0.00140733  0.02262141 -0.03264695]
# doing bisection
# get_fYHg_stepwise: solve with parameters [5.64198992e-03 9.15579107e-01 1.01586256e-05]
# bisection done with mu=0.0009765625 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#    18|4.6799e-02|  3.873e-05|  3.10e+00
# gn_ode: current step is [ 0.0014063   0.02257582 -0.03257873]
# doing bisection
# get_fYHg_stepwise: solve with parameters [5.64233325e-03 9.15584618e-01 2.20483500e-06]
# bisection done with mu=0.000244140625 and 1 function evaluations.
# Iter | Obj func | step size | gradient
#    19|4.6797e-02|  9.678e-06|  3.10e+00
# gn_ode: current step is [ 0.00140608  0.02256416 -0.0325609 ]
# doing bisection
# get_fYHg_stepwise: solve with parameters [5.64241907e-03 9.15585996e-01 2.17475449e-07]
# bisection done with mu=6.103515625e-05 and 1 function evaluations.
# gn_ode: termination by stepsize
# Iter | Obj func | step size | gradient
#    20|4.6797e-02|  2.419e-06|  3.10e+00

# %%
V = np.empty(np.shape(res[1]))
for i in range(6):
    V[:,i] = np.multiply(res[1][:,i], length**3)
fig, axes = plt.subplots(6,1,figsize=(5,10))
for i in range(6):
    axes[i].plot(length,V[:,i])
    axes[i].scatter(length,volume[:,i])
    axes[i].set_xscale('log')
    axes[i].set_xlim([length[0],length[-1]])
    axes[i].title.set_text('t={0}'.format(t[i]))

# %%
import benchmark

# %%
benchmark.discretize('parallel')
# Out:
# discretization of breakage takes  0.612 s.
# discretization of selection takes  0.177 s.

# %%
benchmark.ode('parallel')
# Out:
# constructing ode takes 12.90 μs.

# %%
# %run solve_ode.py
# Out:
# Solving ODE...
# solving ODE took 56.29 seconds

# %%
# %run plotting.py
# Out:
# Solving ODE...
# solving ODE took 55.02 seconds
# /home/lsg/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
# %run plotting.py
# Out:
# Solving ODE...
# solving ODE took 54.67 seconds

# %%
from plotting import plot

# %%
plot([1e-2, 0.7, 0.2])
# Out:
# Solving ODE...
# discretizing...
# solving ODE took 41.87 seconds
# /home/lsg/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
plot([1e-3, 0.7, 0.2])
# Out:
# Solving ODE...
# discretizing...
# solving ODE took 16.21 seconds

# %%
plot([5e-1, 0.6, 0.3])
# Out:
# Solving ODE...
# discretizing...
# solving ODE took 104.14 seconds

# %%
plot([5e-7, 0.6, 0.3])
# Out:
# Solving ODE...
# discretizing...
# solving ODE took 10.68 seconds
# /home/lsg/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
plot([8e-7, 0.5, 0.4])
# Out:
# Solving ODE...
# discretizing...
# solving ODE took 10.12 seconds

# %%
plot([1.49030727e-07, 4.88108313e-01, 3.86786988e-01])
# Out:
# Solving ODE...
# discretizing...
# solving ODE took 10.57 seconds
# /home/lsg/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
# %run lm_ode.py
# Out:
# Iter | Obj func | step size | gradient |   mu   |   rho
#     0|8.0863e+01|   Not cal |  Not cal | 1.7e+10| Not cal
# k is  [8.e-07 5.e-01 4.e-01]
# h is  [-1.15809627e-07 -5.79234111e-09 -7.27198416e-09]
#     1|8.0713e+01|  1.162e-07|  5.66e+05| 5.6e+09| 4.6e+00
# k is  [6.84190373e-07 4.99999994e-01 3.99999993e-01]
# h is  [-2.60108315e-08 -2.07127879e-08 -2.47959657e-08]
#     2|8.0703e+01|  4.148e-08|  1.82e+05| 1.9e+09| 4.1e+00
# k is  [6.58179542e-07 4.99999973e-01 3.99999968e-01]
# h is  [-7.82703292e-09 -6.47157415e-08 -7.66906868e-08]
#     3|8.0702e+01|  1.007e-07|  5.93e+04| 6.2e+08| 3.9e+00
# k is  [6.50352509e-07 4.99999909e-01 3.99999891e-01]
# h is  [-2.51720133e-09 -1.96551959e-07 -2.32220025e-07]
#     4|8.0702e+01|  3.042e-07|  1.96e+04| 2.1e+08| 1.9e+00
# k is  [6.47835307e-07 4.99999712e-01 3.99999659e-01]
# h is  [-8.53654619e-10 -5.91967022e-07 -6.98718183e-07]
#     5|8.0702e+01|  9.158e-07|  6.68e+03| 6.9e+07| 1.0e+00
# k is  [6.46981653e-07 4.99999120e-01 3.99998960e-01]
# h is  [-3.77324974e-10 -1.77796038e-06 -2.09793121e-06]
#     6|8.0701e+01|  2.750e-06|  2.91e+03| 2.3e+07| 9.9e-01
# k is  [6.46604328e-07 4.99997342e-01 3.99996862e-01]
# h is  [-4.14862351e-10 -5.33402704e-06 -6.29335382e-06]
#     7|8.0699e+01|  8.250e-06|  3.08e+03| 7.7e+06| 1.0e+00
# k is  [6.46189466e-07 4.99992008e-01 3.99990569e-01]
# h is  [-1.00673987e-09 -1.59853285e-05 -1.88599685e-05]
#     8|8.0695e+01|  2.472e-05|  7.41e+03| 2.6e+06| 1.0e+00
# k is  [6.45182726e-07 4.99976023e-01 3.99971709e-01]
# h is  [-2.92938469e-09 -4.77883042e-05 -5.63841748e-05]
#     9|8.0681e+01|  7.391e-05|  2.16e+04| 8.5e+05| 1.0e+00
# k is  [6.42253341e-07 4.99928235e-01 3.99915325e-01]
# h is  [-8.63556394e-09 -1.41869124e-04 -1.67408650e-04]
#    10|8.0639e+01|  2.194e-04|  6.46e+04| 2.8e+05| 1.0e+00
# k is  [6.33617777e-07 4.99786366e-01 3.99747916e-01]
# h is  [-2.48157235e-08 -4.12913403e-04 -4.87365372e-04]
#    11|8.0518e+01|  6.388e-04|  1.94e+05| 9.5e+04| 1.0e+00
# k is  [6.08802054e-07 4.99373452e-01 3.99260551e-01]
# h is  [-6.60905740e-08 -1.14257628e-03 -1.34791915e-03]
#    12|8.0184e+01|  1.767e-03|  5.80e+05| 3.2e+04| 1.1e+00
# k is  [5.42711480e-07 4.98230876e-01 3.97912632e-01]
# h is  [-1.47724513e-07 -2.88530640e-03 -3.36592338e-03]
#    13|7.9282e+01|  4.433e-03|  1.70e+06| 1.1e+04| 1.1e+00
# k is  [3.94986967e-07 4.95345569e-01 3.94546708e-01]
# h is  [-2.45956240e-07 -7.23725650e-03 -7.75972035e-03]
#    14|7.6528e+01|  1.061e-02|  6.38e+06| 3.5e+03| 1.7e+00
# k is  [1.49030727e-07 4.88108313e-01 3.86786988e-01]
# h is  [-1.91913174e-07 -2.51714621e-02 -2.10546295e-02]
# /home/lsg/anaconda3/lib/python3.7/site-packages/scipy/integrate/_ivp/common.py:338: RuntimeWarning: overflow encountered in multiply
#   h_new = (y[ind] + new_factor * y_scale[ind]) - y[ind]
# /home/lsg/dev/PBMAS/pbm.py:10: RuntimeWarning: invalid value encountered in matmul
#   return phi_breakage(z, dbs, n, p, delta)
# /home/lsg/anaconda3/lib/python3.7/site-packages/scipy/integrate/_ivp/common.py:347: RuntimeWarning: invalid value encountered in less
#   update = max_diff[ind] * scale_new < max_diff_new * scale[ind]
# /home/lsg/anaconda3/lib/python3.7/site-packages/scipy/integrate/_ivp/common.py:307: RuntimeWarning: overflow encountered in multiply
#   h = (y + factor * y_scale) - y
# /home/lsg/anaconda3/lib/python3.7/site-packages/scipy/integrate/_ivp/common.py:334: RuntimeWarning: invalid value encountered in less
#   diff_too_small = max_diff < NUM_JAC_DIFF_REJECT * scale
# /home/lsg/anaconda3/lib/python3.7/site-packages/scipy/integrate/_ivp/common.py:359: RuntimeWarning: invalid value encountered in less
#   factor[max_diff < NUM_JAC_DIFF_SMALL * scale] *= NUM_JAC_FACTOR_INCREASE
# /home/lsg/anaconda3/lib/python3.7/site-packages/scipy/integrate/_ivp/common.py:360: RuntimeWarning: invalid value encountered in greater
#   factor[max_diff > NUM_JAC_DIFF_BIG * scale] *= NUM_JAC_FACTOR_DECREASE
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/dev/PBMAS/lm_ode.py in <module>
#     124     length, volume, number, Y0, mu, sigma, t, n, N, p, Q = importing(k0)
#     125     args = [length, mu, sigma]
# --> 126     res = lm_ode(pbm.phi, number, t, k0, Q, [1e-3, 1e-8, 1e-8, 1000], *args)
#
# ~/dev/PBMAS/lm_ode.py in lm_ode(phi, yhat, t, params, Q, opts, *args)
#      71                 k_new = k + h
#      72
# ---> 73                 Y, H, g, S, r, fail = eval_objective_func(phi, yhat, t, k_new, n, p, N, Q, S_old, scalar, delta, *args)
#      74
#      75                 dL = h @ (mu * h - g) / 2
#
# ~/dev/PBMAS/solve_tools.py in eval_objective_func(phi, yhat, t, params, n, p, N, Q, S_old, scalar, delta, *args)
#      17     fail = False
#      18
# ---> 19     Z, suc = evolve(phi, Z0, t, params, n, p, delta, *args)
#      20
#      21     if not suc:
#
# ~/dev/PBMAS/solve_ode.py in evolve(phi, z0, t, params, n, p, delta, *args)
#       5     def dzdt(t, z):
#       6         return phi(z, t, params, n, p, delta, *args)
# ----> 7     solution = solve_ivp(dzdt, [t[0],t[-1]], z0, method='Radau', t_eval=t)
#       8     return solution.y, solution.success
#       9
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/integrate/_ivp/ivp.py in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     575     status = None
#     576     while status is None:
# --> 577         message = solver.step()
#     578
#     579         if solver.status == 'finished':
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/integrate/_ivp/base.py in step(self)
#     180         else:
#     181             t = self.t
# --> 182             success, message = self._step_impl()
#     183
#     184             if not success:
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/integrate/_ivp/radau.py in _step_impl(self)
#     443             while not converged:
#     444                 if LU_real is None or LU_complex is None:
# --> 445                     LU_real = self.lu(MU_REAL / h * self.I - J)
#     446                     LU_complex = self.lu(MU_COMPLEX / h * self.I - J)
#     447
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/integrate/_ivp/radau.py in lu(A)
#     318             def lu(A):
#     319                 self.nlu += 1
# --> 320                 return lu_factor(A, overwrite_a=True)
#     321
#     322             def solve_lu(LU, b):
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/linalg/decomp_lu.py in lu_factor(a, overwrite_a, check_finite)
#      70     """
#      71     if check_finite:
# ---> 72         a1 = asarray_chkfinite(a)
#      73     else:
#      74         a1 = asarray(a)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in asarray_chkfinite(a, dtype, order)
#     496     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
#     497         raise ValueError(
# --> 498             "array must not contain infs or NaNs")
#     499     return a
#     500
#
# ValueError: array must not contain infs or NaNs

# %%
import matplotlib.pyplot as plt
import numpy as np

V = np.empty(np.shape(res[1]))
for i in range(6):
    V[:,i] = np.multiply(res[1][:,i], length**3)
fig, axes = plt.subplots(6,1,figsize=(5,10))
for i in range(6):
    axes[i].plot(length,V[:,i])
    axes[i].scatter(length,volume[:,i])xx
    axes[i].set_xscale('log')
    axes[i].set_xlim([length[0],length[-1]])
    axes[i].title.set_text('t={0}'.format(t[i]))

# %%
a = np.array([1, 1])

# %%
any(a < 0)
# Out:
# False

# %%
def logi(x):
    return 1 / (1 + np.exp(-10*(x-2.0)))

# %%
xx = np.linspace(1, 3, 100)

# %%
plt.plot(xx, logi(xx))
